# %% [markdown]
# # Summary
#
# Scientists and users of beamlines need to know where glitches occur to explain the sharp dips in intensity they observe in their results. In EXAFS measurements for example some glitches disappear due to ratio-ing out but not all do. By knowing where the glitches appear they can confirm that is, or is not, what they see in their results.
# Another possible use is to decide before the experiment is done the most suitable range of energy to use in order to avoid the maximum amount of glitches.
#
# In order to have this information one can refer to experimental data, such as the data found on ssrl glitch database, or to simulated data.
#
# The work explained here concerns the latter, the Monte-Carlo x-ray simulation software McXtrace is used to find these glitches. The aim is to have a general purpose glitch "finder" or glitch "runner".
#
# To verify the validity of the simulation the results are compared with the experimental data of the ssrl glitch database.
#
# Some python code that finds the positions of glitches is also used as a base of comparison. In the following text these glitches are called "theory glitches".
#
# To visualize and summarize the results an overlap of the ssrl glitch db data with the McXtrace data and the "theory glitches" data is plotted.
#
# When comparing McXtrace and the ssrl glitch database, glitches are found at the same positions for the same crystals and orientations. Work still needs to be done to get the same intensity deviation with McXtrace compared to the ssrl glitch database.
#
#
# # Diffraction glitches
#
# Glitches occur when, for a specific energy, the Bragg law is respected for multiple (hkl) planes at the same time (2 or more).
#
#
# d<sub>1</sub>\*sin(θ<sub>1</sub>) = d<sub>2</sub>\*sin(θ<sub>2</sub>) = ... = d<sub>n</sub>\*sin(θ<sub>n</sub>)
#
# with d<sub>1</sub>, d<sub>2</sub>, ..., d<sub>n</sub> the interplanar spacings and θ<sub>1</sub>, θ<sub>2</sub>, ..., θ<sub>n</sub>  the Bragg angles in a glitch condition.
#
# The primary plane of diffraction is the (hkl) plane that is oriented parallel to the crystal's surface. Due to one or more other planes partly diverting the rays, less rays are reflected off of the primary plane of diffraction.
# The beam signal lowers in intensity in a sharp manner.
#
# ![glitches image](images/glitches_corrige_cropped.png)
#
#
#
#
# # Simulations procedure
#
# ## Theory glitches simulation
#
# The following code finds the positions of glitches on a desired range of energy by using Bragg's law `2*d*sin(θ)=n*λ`. The code is fed a file with a list of (hkl) planes for that energy range and their structure factors. This file has been generated with the software [cif2hkl](https://gitlab.com/soleil-data-treatment/soleil-software-projects/cif2hkl).
# The code loops over all the planes, i.e. all the interplanar spacings d<sub>hkl</sub>'s for each energy, a step of one eV at a time. Other than the d<sub>HKL</sub> and θ<sub>HKL</sub> of the primary plane of diffraction (`(HKL)` is written in capital letters to indicate these are the miller indices of the primary plane of diffraction) if a d<sub>hkl</sub> and θ<sub>hkl</sub> also satisfy the Bragg law, it is a glitch.
#
# In the following the B<sub>hkl</sub> basis is mentioned, it is the basis we place ourselves in to express the unit cell and have the [HKL] vector(normal to the crystal's surface) together with two other [hkl] vectors form the direct trihedron.
#
# Here is some pseudo-code:
#
# ```
# for every energy, 1ev at a time:
#     get the Bragg angle for plane (HKL)
#     get normalized k, the incident wave vector, in B_hkl basis
#     for each (hkl) plane:
#         get normalized [hkl] vector in B_hkl basis
#         get the angle at which k hits the (hkl) plane, gives d_hkl and θ_hkl
#         get energy selected by plane (HKL)
#         get energy selected by plane (hkl)
#         if energy_HKL-1 <= energy_hkl <= energy_HKL+1
#             It is a glitch
#
# ```
#
#
# The code writes in a file if a glitch is present or not for a certain energy.
# In another file it writes when a glitch is present one (or more) [h,k,l,F^2,d_hkl,θ_hkl] (F^2 being the squared structure factor for the plane (hkl)) for each plane constituting the glitch.
# Finally, the code checks which (hkl) planes contribute to each glitch and assigns a deviation intensity by adding their respective `F^2` reflection values. Adding the reflection values this way to get a deviation intensity is a simplified estimation.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import math as m
import numpy as np
import re

############## Express unit cell basis. The canonical basis B = {e1, e2, e3}.
e1= np.array([[1,0,0]])

e2= np.array([[0,1,0]])

e3= np.array([[0,0,1]])

############## Express hkl1 hkl2 hkl3 in unit cell basis. The hkl basis, B_hkl = {hkl1, hkl2, hkl3}.
#hkl1 = np.array([[1,-1,2]]), rectified, having this is not a right handed coord system, it is left handed
hkl1 = np.array([[-1,1,-2]])
hkl1_norm = m.sqrt(np.dot(hkl1.reshape((1,3)),hkl1.reshape((3,1))))
hkl1 = hkl1/hkl1_norm

hkl2 = np.array([[-1,1,1]])
hkl2_norm = m.sqrt(np.dot(hkl2.reshape((1,3)),hkl2.reshape((3,1))))
hkl2 = hkl2/hkl2_norm

hkl3 = np.array([[2,2,0]])
hkl3_norm = m.sqrt(np.dot(hkl3.reshape((1,3)),hkl3.reshape((3,1))))
hkl3 = hkl3/hkl3_norm

############## change-of-basis matrix
#https://www.youtube.com/watch?v=hVmcRYD1KFQ
#https://www.youtube.com/watch?v=CNIN7UpyXvo
mat2 = np.array([[np.dot(e1.reshape((1,3)),hkl1.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl1.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl1.reshape((3,1)))[0][0]],
                 [np.dot(e1.reshape((1,3)),hkl2.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl2.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl2.reshape((3,1)))[0][0]],
                 [np.dot(e1.reshape((1,3)),hkl3.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl3.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl3.reshape((3,1)))[0][0]]])

############## get the h,k,l F squared values from Si.lau
#number of (hkl) planes in the Si.lau file
sizeb=43744

h = []
k = []
l = []
reflec = []
i=0
with open("Si_parsed.lau") as file:
    for line in file:
        aaa=line.strip(" ").strip("\n")
        aaa = re.sub(' +',' ',aaa)      
        elt = aaa.split(" ")
        h.append(float(elt[0]))
        k.append(float(elt[1]))
        l.append(float(elt[2]))
        reflec.append(elt[5])
        i+=1

glitch_dict={}

############## Loop over a range of energies, advance one eV at a time
#For the full energy range, input 4500 to 27000 eV
energy_initial = int(input("Input initial energy(eV):"))
energy_final = int(input("Input final energy(eV):"))

for egy in range(energy_initial,energy_final,1):
    ## Bragg angle / energy we select at
    #hits main plane with this bragg angle, equivalent to that energy
    h_main_plane = 2
    k_main_plane = 2
    l_main_plane = 0
    energy = egy    
    bragg_angle = (180/m.pi)*m.asin(12398.4198/(energy*2*(5.43096/m.sqrt(h_main_plane*h_main_plane+k_main_plane*k_main_plane+l_main_plane*l_main_plane))))
    print("bragg_angle",bragg_angle,"energy",energy)

    #PHI 90
    #k directly written in basis B_hkl
    #incoming ray
    kx=m.cos(bragg_angle*m.pi/180)
    ky=0
    kz=-m.sin(bragg_angle*m.pi/180)

    k_vector = np.array([[kx,ky,kz]])
    #normalise it
    k_vector_norm = m.sqrt(np.dot(k_vector.reshape((1,3)),k_vector.reshape((3,1))))
    k_vector = k_vector/k_vector_norm
    k_vector_basis_hkl = k_vector.reshape((3,1))

    glitches=[]
    i=0
    for elt in h:
        #[hkl] vector
        hkl = np.array([[h[i],k[i],l[i]]])
        #normalise it
        hkl_norm = m.sqrt(np.dot(hkl.reshape((1,3)),hkl.reshape((3,1))))
        hkl = hkl/hkl_norm

        #express the [hkl] vector in basis B_hkl
        hkl_basis_hkl = np.dot(mat2,hkl.reshape((3,1)))
        
        #Now that we now both have our k and [hkl] vector expressed in the same basis, B_hkl
        #we can calculate with the norm to the plane (ie [hkl] vector) and our k, the angle at which k hits the (hkl) plane   
        #see https://www.youtube.com/watch?v=wtpwM2y86So
        if ((np.dot(k_vector_basis_hkl.reshape((1,3)),hkl_basis_hkl.reshape((3,1)))[0][0])>=1):
            alpha = (180/m.pi)*m.acos((1)/(1*1)) #1*1 because i have normalised them
        elif ((np.dot(k_vector_basis_hkl.reshape((1,3)),hkl_basis_hkl.reshape((3,1)))[0][0])<=-1):
            alpha = (180/m.pi)*m.acos((-1)/(1*1))
        else:
            alpha = (180/m.pi)*m.acos((np.dot(k_vector_basis_hkl.reshape((1,3)),hkl_basis_hkl.reshape((3,1)))[0][0])/(1*1)) #1*1 because i have normalised them
        
        if ((np.dot(k_vector_basis_hkl.reshape((1,3)),-hkl_basis_hkl.reshape((3,1)))[0][0])>=1):
            alpha2 = (180/m.pi)*m.acos((1)/(1*1)) #1*1 because i have normalised them
        elif ((np.dot(k_vector_basis_hkl.reshape((1,3)),-hkl_basis_hkl.reshape((3,1)))[0][0])<=-1):
            alpha2 = (180/m.pi)*m.acos((-1)/(1*1))
        else:
            alpha2 = (180/m.pi)*m.acos((np.dot(k_vector_basis_hkl.reshape((1,3)),-hkl_basis_hkl.reshape((3,1)))[0][0])/(1*1)) #1*1 because i have normalised them

        angle_alpha = min(alpha,alpha2)
        theta = 90 - angle_alpha

        d1 = 5.43096/m.sqrt(h_main_plane*h_main_plane+k_main_plane*k_main_plane+l_main_plane*l_main_plane) #in unit cell basis
        theta_1 = bragg_angle

        d2 = 5.43096/m.sqrt(h[i]*h[i]+k[i]*k[i]+l[i]*l[i]) #in unit cell basis
        theta_2 = theta

        if(theta_2!=0):
            energy_selected_main_plane = 12398.4198/(2*d1*m.sin(theta_1*m.pi/180))
            energy_selected_parisitic_plane = 12398.4198/(2*d2*m.sin(theta_2*m.pi/180))
            if((energy_selected_main_plane-1)<=energy_selected_parisitic_plane<=(energy_selected_main_plane+1)):
                #check to see if it is the main plane or -(main plane) , if it is dont add it as glitch
                if(not (h[i]==2 and k[i]==2 and l[i]==0) and  not(h[i]==-2 and k[i]==-2 and l[i]==0)):
                    glitches.append([h[i],k[i],l[i],reflec[i],theta_2,d2])

        i+=1

    glitch_dict[energy]=glitches

x = []
y = []

for egy in range(energy_initial,energy_final,1):
    x.append(egy)
    if(len(glitch_dict[egy])>=1):
        y.append(1)        
    else:
        y.append(0)

############## Write if we have found a glitch (1) or not (0) for the different energies we looped over.
with open('glitches_positions.txt', 'w') as f:
    i = 0
    for elt in x:
        f.write(str(elt)+' '+str(y[i]))
        f.write('\n')
        i+=1
    
############## Write details. Ie h, k, l, F squared and finally the angle (at which our incoming k vector hits the (hkl) plane) and d_hkl for that glitch.
with open('glitches_details.txt', 'w') as f:
    i = 0
    for egy in range(energy_initial,energy_final,1):
        if(len(glitch_dict[egy])>=1):
            f.write("### "+str(egy))
            f.write('\n')        
            for elt in glitch_dict[egy]:
                f.write(str(elt[0])+' '+str(elt[1])+' '+str(elt[2])+' '+str(elt[3])+' '+str(elt[4])+' '+str(elt[5]))
                f.write('\n')            

############## Read glitches_details.txt file and for each glitch assign a deviation intensity by adding their respective `F^2` plane reflection values.
#The resulting deviation intensity is a simplified estimation.
egy_itsty = {}
egy=0
itsty_sum = 0

with open("glitches_details.txt") as file: #read glitches_details file
    for line in file:
        iii = re.sub(' +',' ',line)
        eltee = iii.strip("\n").strip(" ").split(" ")
        if(len(eltee)==2):
            if(itsty_sum!=0):
                egy_itsty[egy]=itsty_sum
                itsty_sum=0
                egy=int(eltee[1])
            else:
                egy=int(eltee[1])
            
        if(len(eltee)==6):
            itsty_sum+=float(eltee[3])

with open('theory_itsty_firstxtal.dat', 'w') as f:
    i = energy_initial
    while(i<=energy_final):
        if i in egy_itsty.keys():
            f.write(str(i)+ " "+str(egy_itsty[i]))
            f.write("\n")    
        else: 
            f.write(str(i)+ " "+"0")
            f.write("\n")        
        i+=1

print("Theory glitches have been written in a file called 'theory_itsty_firstxtal.dat'.")

# %% [markdown]
# ## McXtrace simulation
#
# ### Beamline 11-2
#
# The 11-2 beamline is described in detail [here](https://www-ssrl.slac.stanford.edu/mes/11-2/manual.php).
# Beamline 11-2's source is a 26 poles wiggler with a range of 4 to 40 keV, a 175mm period and a 2 Tesla magnet. It's horizontal and vertical divergence is respectively 1.5mrad and 0.15mrad.
# The ring current used is 0.1 A and the ring electron energy is 2.4 GeV.
#
# The ssrl glitch data for the 11-2 beamline was made by using the beamline in the [unfocussed and uncollimated mode](https://www-ssrl.slac.stanford.edu/mes/Glitch_Curves/).
# This means there is no focusing and collimating mirror. The ray hits the monochromator situated at 17.6m downstream from the source and is reflected towards the detector situated 27.5-29.5m downstream from the source.
#
# ### Orienting the (hkl) planes
#
# #### ssrl plots
#
# Since the results will be compared with the ssrl glitch db data, the monochromators need to be oriented the same way ssrl has them oriented.
# The aim is to reproduce the glitches found [here](https://www-ssrl.slac.stanford.edu/smbin/dataextractnew.pl) for the crystal Si 220 phi 90 (ssrl glitch db uses `phi 0` and `phi 90` notation that is explained [further below](#phi-0-and-phi-90)).
#
# In the picture below, the intensity deviation as a function of the energy is plotted for the crystal Si 220 with phi=90 for the beamline [BL 11-2](https://www-ssrl.slac.stanford.edu/content/beam-lines/bl11-2). Click [here](https://www-ssrl.slac.stanford.edu/smbin/dataextractnew.pl?trace1=si22090112&trace2=None&trace3=None&trace4=None&lowrange=4.5&highrange=27&graph=1&kvalyes=0) to access it directly on ssrl-glitch db.
#
#
# ![intensity deviation plot](images/ssrldb_si220_phi90_cropped.png)
#
#
#
#
#
# #### Phi 0 and phi 90 notation
# Phi 0 and phi 90 relate to how the crystal is positioned.
# For the beamline 11-2 case used in this notebook, only one position is used, PHI 90.
#
# The [220] hkl vector is normal to the crystal's surface. The two other vectors that make up the direct trihedron are along the [1-12] and [-111] hkl vectors. The following picture illustrates this:
# ![phi 0 and phi 90](images/phi_glitches.png)
#
#
# Starting from the phi 0 position (left), the position ends up in the phi 90 position (right) after a 90 degrees rotation around the [220] hkl vector.
#
# In the simulation of McXtrace the (hkl) planes need to be oriented properly.
#
# #### Expressing the coordinates of the unit cell
#
# Any vector of the unit cell basis B can be expressed in the B<sub>hkl</sub> basis (the B<sub>hkl</sub> basis being the one represented in the above picture).
# The [220] hkl vector is positioned along the z axis, the [1 -1 2] hkl vector along the y axis and the [-1 1 1] hkl vector along the x axis.
#
# This is done in order to position ourselves on the B<sub>hkl</sub> basis, and express the unit cell basis B in it.
# These coordinates are then written in the McXtrace .instr files in parameters called ax,ay,az, bx,by,bz and cx,cy,cz.
#
# ![basis explanation](images/basis_explanation_cropped.png)
#
# The above is done in the following code.
#
# For this case, inputting the vector 100, 010 and 001 (the normalized vectors of the unit cell basis B) will give the ax,ay,az, bx,by,bz and cx,cy,cz written in the McXtrace simulation files.

# %%
import math as m
import numpy as np

############## Express xyz vector (chose whichever one you want) in unit cell basis.
#Input (1,0,0) then (0,1,0) then (0,0,1).
x=float(input("Input x component of the vector in unit cell basis:"))
y=float(input("Input y component of the vector in unit cell basis:"))
z=float(input("Input z component of the vector in unit cell basis:"))
print(x,y,z)
xyz = np.array([[x,y,z]])
#normalise it
xyz_norm = m.sqrt(np.dot(xyz.reshape((1,3)),xyz.reshape((3,1))))
xyz = xyz/xyz_norm

############## Express unit cell basis. The canonical basis B = {e1, e2, e3}.
e1= np.array([[1,0,0]])

e2= np.array([[0,1,0]])

e3= np.array([[0,0,1]])

############## Express hkl1 hkl2 hkl3 in unit cell basis. The hkl basis, B_hkl = {hkl1, hkl2, hkl3}.
#hkl1 = np.array([[1,-1,2]]), rectified, having this is not a right handed coord system, it is left handed
hkl1 = np.array([[-1,1,-2]])
hkl1_norm = m.sqrt(np.dot(hkl1.reshape((1,3)),hkl1.reshape((3,1))))
hkl1 = hkl1/hkl1_norm

hkl2 = np.array([[-1,1,1]])
hkl2_norm = m.sqrt(np.dot(hkl2.reshape((1,3)),hkl2.reshape((3,1))))
hkl2 = hkl2/hkl2_norm

hkl3 = np.array([[2,2,0]])
hkl3_norm = m.sqrt(np.dot(hkl3.reshape((1,3)),hkl3.reshape((3,1))))
hkl3 = hkl3/hkl3_norm

############## change-of-basis matrix
#https://www.youtube.com/watch?v=hVmcRYD1KFQ
#https://www.youtube.com/watch?v=CNIN7UpyXvo
mat2 = np.array([[np.dot(e1.reshape((1,3)),hkl1.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl1.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl1.reshape((3,1)))[0][0]],
                 [np.dot(e1.reshape((1,3)),hkl2.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl2.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl2.reshape((3,1)))[0][0]],
                 [np.dot(e1.reshape((1,3)),hkl3.reshape((3,1)))[0][0], np.dot(e2.reshape((1,3)),hkl3.reshape((3,1)))[0][0], np.dot(e3.reshape((1,3)),hkl3.reshape((3,1)))[0][0]]])

############## xyz is now expressed in the hkl basis B_hkl
xyz_basis_hkl = np.dot(mat2,xyz.reshape((3,1)))
print("xyz vector expressed in basis hkl: ", xyz_basis_hkl)
# Out:
# Input x component of the vector in unit cell basis:0
# Input y component of the vector in unit cell basis:0
# Input z component of the vector in unit cell basis:1
# 0.0 0.0 1.0
# xyz vector expressed in basis hkl:  [[-0.81649658]
#  [ 0.57735027]
#  [ 0.        ]]

# %% [markdown]
# ### Two types of sources
#
# The simulations are run for two types of sources: a white source and a nearly monochromatic source (dE). The nearly monochromatic source is used to get better statistics in the McXtrace simulations.
# It is mean by better statistics that there are more rays of the bragg energy hitting the crystals and being detected in the monitors. This is because the rays emitted by the source are contained in a narrower dE bandwith around the bragg energy. Whereas when the white source is used, the much larger dE bandwith will decrease the density of rays around the bragg energy.
# Using the narrower dE source has also for effect to speed up the simulation runtime because it is possible to decrease the necessary number of rays thanks to the better statistics previously described.
#
# #### White light, detuning for harmonic rejection
#
# The white light source has a dE=18 keV and is centered on E=22 keV, the range is therefore from 4 to 40 keV. The higher harmonics are eliminated by detuning the second crystal.
#
# ##### Detuning
#
# A rocking curve, calculated for a specific energy, was done in a simple manner by having the second crystal rotate and having a fixed slit and detector at the Bragg's angle of the selected energy.
#
# Detuning to remove the harmonics was done by rotating counter clock wise the second crystal by 50% of the rocking curve's full width half maximum.
#
# Best results are yielded with 50% of the rocking curve's fwhm for all points in the energy range being scanned.
#
# Below is a picture that explains the concept of detuning.
#
# ![detuning](images/detuning_explanation_done_cropped.png)
#
#
# #### Monochromatic light
#
# The (nearly) monochromatic light source is centered on E has a dE of 100eV and scans an energy range 1eV at a time. The channel cut turns at the appropriate Bragg angle to select the energy of the source E.
# Detuning is not necessary for the monochromatic light because harmonics can't be present due to the source's small divergence.

# %% [markdown]
# ## Run McXtrace simulations
#
# ### McStasScript
#
# [McStasScript](https://github.com/PaNOSC-ViNYL/McStasScript) is an API for creating and running McStas/McXtrace instruments from python scripting.
# It will be used in this notebook to create and run the McXtrace instruments.
# It is also possible to run these instruments independently from McStasScript.
# Two different instruments will be used, firstly a white source and then a (nearly) monochromatic light source, the latter used only for speeding up the simulation's runtime and better statistics.
#
# #### White light
#
# ##### Instrument

# %%
import mcstasscript as ms

my_instrument = ms.McXtrace_instr("mcstasscript_bl_11_2_white_src",input_path="./mcxtrace_bl_11_2_white_src")

dict_params = {}

dict_params["Etohit"] = "6900"
dict_params["h"] = "2"
dict_params["k"] = "2"
dict_params["l"] = "0"
dict_params["fwhm"] = 0.1
dict_params["detuning_percentage"] = 0 
dict_params["detuning_rockingcurve"] = 0

my_instrument.add_parameter("Etohit")
my_instrument.add_parameter("h")
my_instrument.add_parameter("k")
my_instrument.add_parameter("l")
my_instrument.add_parameter("fwhm")
my_instrument.add_parameter("detuning_percentage")
my_instrument.add_parameter("detuning_rockingcurve")

my_instrument.set_parameters(dict_params)

my_instrument.add_declare_var("double", "n")
my_instrument.add_declare_var("double", "calculated_angle")
my_instrument.add_declare_var("double", "theta_detuning")

my_instrument.append_initialize("n = h*h + k*k + l*l;")
my_instrument.append_initialize("fprintf(stdout,\"n %g \\n\", n);")
my_instrument.append_initialize("calculated_angle=RAD2DEG*asin(12398.4198*sqrt(n)/(2*5.43096*Etohit));")
my_instrument.append_initialize("fprintf(stdout,\"Energy eV %g / Angle deg %g \\n\", Etohit, calculated_angle);")
my_instrument.append_initialize("//the fwhm is 0.1 degrees by default, the value for the for 6900-7500 eV range. For other ranges find it by doing a scan with the detuning_rockingcurve parameter.")
my_instrument.append_initialize("theta_detuning=(detuning_percentage/100)*fwhm;")
my_instrument.append_initialize("fprintf(stdout,\"theta_detuning degrees %g \\n\", theta_detuning);")    
        
my_origin = my_instrument.add_component("Origin", "Progress_bar", AT=[0,0,0])

#my_instrument.show_parameters()

my_source = my_instrument.add_component("src", "Wiggler", AT=[0,0,0], RELATIVE="PREVIOUS")
my_source.E0 = 22
my_source.dE = 18
my_source.B = 2
my_source.Nper = 13
my_source.Ie = 0.1
my_source.length = 175e-3
my_source.Ee = 2.4
my_source.focus_xw = "2*tan(0.0015/2)"
my_source.focus_yh = "2*tan(0.00015/2)"

my_slit_mono = my_instrument.add_component("slit_mono", "Slit", AT=[0,0,17.6-0.08], RELATIVE="PREVIOUS")
my_slit_mono.xwidth = 0.005
my_slit_mono.yheight = 0.0003

my_mono_loc = my_instrument.add_component("mono_loc", "Arm", AT=[0,0,0.08], RELATIVE="PREVIOUS")

#ray's position, this is used to place monitors after the dcm
my_ray_position = my_instrument.add_component("ray_position", "Arm", AT=[0,0,0], RELATIVE="PREVIOUS")

# -------------------------------------------------------------------------- Double crystal monochromator 
my_mono_rotation = my_instrument.add_component("mono_rotation", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[-90,0,0], ROTATED_RELATIVE="PREVIOUS")

my_mono_rotation_phi_90 = my_instrument.add_component("mono_rotation_phi_90", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[0,0,-90], ROTATED_RELATIVE="PREVIOUS")

#0.006 works too though
my_center_of_rotation = my_instrument.add_component("center_of_rotation", "Arm", AT=[0,0,0.004], AT_RELATIVE="PREVIOUS", ROTATED=[0,"-calculated_angle",0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_split = my_instrument.add_component("bragg_crystal_split", "Single_crystal", AT=[-0.0762/2, 0, -0.006/2-(0.001/2)], AT_RELATIVE="PREVIOUS",ROTATED=[0,0,0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_split.reflections = "\"Si.lau\""
my_bragg_crystal_split.material = "\"Si.txt\""
my_bragg_crystal_split.xwidth = 76.2e-3
my_bragg_crystal_split.yheight =  41.275e-3
my_bragg_crystal_split.zdepth = 0.001
my_bragg_crystal_split.p_transmit = -1
my_bragg_crystal_split.order = 1
my_bragg_crystal_split.mosaic = 1
my_bragg_crystal_split.barns = 1
my_bragg_crystal_split.ax = -5.43096*0.40824829
my_bragg_crystal_split.ay = -5.43096*0.57735027
my_bragg_crystal_split.az = 5.43096*0.70710678
my_bragg_crystal_split.bx = 5.43096*0.40824829
my_bragg_crystal_split.by = 5.43096*0.57735027
my_bragg_crystal_split.bz = 5.43096*0.70710678
my_bragg_crystal_split.cx = -5.43096*0.81649658
my_bragg_crystal_split.cy = 5.43096*0.57735027
my_bragg_crystal_split.cz = 5.43096*0
my_bragg_crystal_split.append_EXTEND("if(!SCATTERED) ABSORB;")
my_bragg_crystal_split.set_SPLIT(10)

my_mono_loc_2 = my_instrument.add_component("mono_loc_2", "Arm", AT=[0.09525/2, 0, 0.006/2+(0.001/2)], RELATIVE="center_of_rotation")

#counter clock wise detuning
#use detuning_rockingcurve or theta_detuning, not both
my_detuning_rotation = my_instrument.add_component("detuning_rotation", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[0,"-detuning_rockingcurve-theta_detuning",0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_two_split = my_instrument.copy_component("bragg_crystal_two_split", "bragg_crystal_split", AT=[0, 0, 0], AT_RELATIVE="PREVIOUS",ROTATED=[0,0,0], ROTATED_RELATIVE="PREVIOUS")
my_bragg_crystal_two_split.xwidth = 95.25e-3
my_bragg_crystal_two_split.append_EXTEND("if(!SCATTERED) ABSORB;")
my_bragg_crystal_two_split.set_SPLIT(10)

# -------------------------------------------------------------------------- Energy monitors
my_EnergyMonitor_first = my_instrument.add_component("EnergyMonitor_first", "Monitor_nD", AT=[0, "0.006*sin(DEG2RAD*2*calculated_angle)/sin(DEG2RAD*calculated_angle)", 18.6-17.6], RELATIVE="ray_position")
my_EnergyMonitor_first.xwidth = 44e-4
my_EnergyMonitor_first.yheight = 44e-4
my_EnergyMonitor_first.min = 4
my_EnergyMonitor_first.max =  40
my_EnergyMonitor_first.bins = 500
my_EnergyMonitor_first.options = "\"energy\""
my_EnergyMonitor_first.filename = "\"EnergyMonitor_first\""
my_EnergyMonitor_first.restore_xray = 1

my_EnergyMonitor_second = my_instrument.copy_component("EnergyMonitor_second", "EnergyMonitor_first", AT=[0, 0, 0], RELATIVE="PREVIOUS")
my_EnergyMonitor_second.xwidth = 2.8e-3
my_EnergyMonitor_second.yheight = 2.8e-3
my_EnergyMonitor_second.filename = "\"EnergyMonitor_second\""

my_EnergyMonitor_third = my_instrument.copy_component("EnergyMonitor_third", "EnergyMonitor_first", AT=[0, 0, 10], RELATIVE="PREVIOUS")
my_EnergyMonitor_third.xwidth = 1e-2
my_EnergyMonitor_third.yheight = 1e-2
my_EnergyMonitor_third.filename = "\"EnergyMonitor_third\""

my_EnergyMonitor_fourth = my_instrument.copy_component("EnergyMonitor_fourth", "EnergyMonitor_first", AT=[0, 0, 0], RELATIVE="PREVIOUS")
my_EnergyMonitor_fourth.xwidth = 4.3e-3
my_EnergyMonitor_fourth.yheight = 4.3e-3
my_EnergyMonitor_fourth.filename = "\"EnergyMonitor_fourth\""

#my_instrument.settings(output_path="bl_11_2_white_src_res", mpi=4, ncount=1E7) # mpi=4, does not work in this notebook todo later

#my_instrument.settings(output_path="./mcxtrace_bl_11_2_white_src/rocking_curve/bl_11_2_white_src_res", mpi=4, ncount=1E5) # mpi=4, does not work in this notebook todo later

my_instrument.settings(output_path="./mcxtrace_bl_11_2_white_src/rocking_curve/bl_11_2_white_src_res", ncount=1E6) # mpi=4, does not work in this notebook todo later


print("Instrument BL 11-2 white source configured.")
# Out:
# Instrument BL 11-2 white source run.

# %% [markdown]
# ##### Rocking curve, detuning

# %%
# ---------------------------------------------------- Input rocking angle in degrees (0.1 deg for ex)
# and the number of points in the scan (25 for ex)
rocking_angle = float(input("Input rocking degree(>0 deg):")) 
nb_pts_scan = int(input("Input number of points in the scan:")) 

rocking_angle_scan_range = []

angle = -rocking_angle
print("initial angle:" ,angle)

angle_step = 2*rocking_angle /  (nb_pts_scan-1)
while angle<=rocking_angle:
    rocking_angle_scan_range.append(angle)    
    angle += angle_step
    print(angle)
  
data_list = []

for angle in rocking_angle_scan_range:
    dict_params["detuning_rockingcurve"] = angle
    print("running simulation for angle: ",angle)
    my_instrument.set_parameters(dict_params)
    data = my_instrument.backengine()
    data_list.append(data)
    my_instrument.settings(force_compile=False)

my_instrument.settings(force_compile=True)

# ---------------------------------------------------- Writing to file
#writing the equivalent of mccode.dat, getting the total intensity of the 4 monitors
counter = 0

with open('./mcxtrace_bl_11_2_white_src/rocking_curve/mccode_mcstasscript_rocking_angle.dat', 'w') as f:    
    for angle in rocking_angle_scan_range:
        #print(angle)
        f.write(str(angle))
        f.write(" "+data_list[counter][0].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][1].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][2].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][3].metadata.info['values'].split(" ")[0])        
        f.write("\n")    
        counter+=1

import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------------------------- Plotting rocking angle
########### Get data from McXtrace's mccode_mcstasscript_rocking_angle.dat
screen=1
data_mcxtrace = np.loadtxt("./mcxtrace_bl_11_2_white_src/rocking_curve/mccode_mcstasscript_rocking_angle.dat")
size_data_mcxtrace = len(data_mcxtrace)
X_rocking = np.zeros(size_data_mcxtrace)
Y_rocking = np.zeros(size_data_mcxtrace)


i=0
for elt in data_mcxtrace:    
    X_rocking[i]=elt[0]
    Y_rocking[i]=elt[screen]
    i+=1


plt.title("Rocking curve.")
plt.xlabel("rocking angle (deg)")
plt.ylabel("I")

plt.plot(X_rocking, Y_rocking, marker='.', color="g", label='McXtrace')

plt.legend(fontsize=10)
plt.show()
# Out:
# Input rocking degree(>0 deg):0.1
# Input number of points in the scan:20
# initial angle: -0.1
# -0.08947368421052632
# -0.07894736842105263
# -0.06842105263157894
# -0.057894736842105256
# -0.047368421052631574
# -0.03684210526315789
# -0.02631578947368421
# -0.015789473684210527
# -0.005263157894736843
# 0.005263157894736841
# 0.015789473684210527
# 0.02631578947368421
# 0.03684210526315789
# 0.047368421052631574
# 0.057894736842105256
# 0.06842105263157894
# 0.07894736842105263
# 0.08947368421052632
# 0.1
# 0.1105263157894737
# running simulation for angle:  -0.1
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_82"
# INFO: Regenerating c-file: mcstasscript_bl_11_2_white_src.c
# Warning: Component Origin=Progress_bar(string profile) definition parameter
#          may be changed into a setting parameter to avoid
#          warnings at compile time.
# Info:    Defining SPLIT from bragg_crystal_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# Info:    Defining SPLIT from bragg_crystal_two_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# CFLAGS=
#           INFO: Recompiling: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 24 [s] % 44 54 64 74 84 94
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0 EnergyMonitor_first_ERR=0 EnergyMonitor_first_N=0 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=0 EnergyMonitor_second_ERR=0 EnergyMonitor_second_N=0 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=0 EnergyMonitor_third_ERR=0 EnergyMonitor_third_N=0 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=0 EnergyMonitor_fourth_ERR=0 EnergyMonitor_fourth_N=0 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_82]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_82
#
# running simulation for angle:  -0.08947368421052632
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_83"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 27 [s] % 40 50 60 70 80 90
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0 EnergyMonitor_first_ERR=0 EnergyMonitor_first_N=0 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=0 EnergyMonitor_second_ERR=0 EnergyMonitor_second_N=0 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=0 EnergyMonitor_third_ERR=0 EnergyMonitor_third_N=0 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=0 EnergyMonitor_fourth_ERR=0 EnergyMonitor_fourth_N=0 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_83]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_83
#
# running simulation for angle:  -0.07894736842105263
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_84"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 25 [s] % 42 52 62 72 82 92
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0.0538634 EnergyMonitor_first_ERR=0.0145841 EnergyMonitor_first_N=57 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=0.0048364 EnergyMonitor_second_ERR=0.00197446 EnergyMonitor_second_N=14 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=139.514 EnergyMonitor_third_ERR=56.258 EnergyMonitor_third_N=193 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=0.00671088 EnergyMonitor_fourth_ERR=0.00203009 EnergyMonitor_fourth_N=37 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_84]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_84
#
# running simulation for angle:  -0.06842105263157894
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_85"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 28 [s] % 38 48 58 68 78 88 98
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=3544.88 EnergyMonitor_first_ERR=600.381 EnergyMonitor_first_N=270 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=19.5278 EnergyMonitor_second_ERR=8.75679 EnergyMonitor_second_N=37 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=10546.8 EnergyMonitor_third_ERR=3062.65 EnergyMonitor_third_N=356 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=300.602 EnergyMonitor_fourth_ERR=114.741 EnergyMonitor_fourth_N=111 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_85]. Time: 27 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_85
#
# running simulation for angle:  -0.057894736842105256
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_86"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 22 [s] % 48 58 68 78 88 98
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=569955 EnergyMonitor_first_ERR=59756.2 EnergyMonitor_first_N=442 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=397521 EnergyMonitor_second_ERR=51145.2 EnergyMonitor_second_N=272 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=3.68576e+06 EnergyMonitor_third_ERR=682337 EnergyMonitor_third_N=1091 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=518742 EnergyMonitor_fourth_ERR=59125.8 EnergyMonitor_fourth_N=324 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_86]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_86
#
# running simulation for angle:  -0.047368421052631574
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_87"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 25 [s] % 43 53 63 73 83 93
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=1.2753e+08 EnergyMonitor_first_ERR=7.44505e+06 EnergyMonitor_first_N=1244 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=9.467e+07 EnergyMonitor_second_ERR=6.42344e+06 EnergyMonitor_second_N=592 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.4055e+08 EnergyMonitor_third_ERR=7.49299e+06 EnergyMonitor_third_N=2145 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=8.44177e+07 EnergyMonitor_fourth_ERR=5.78302e+06 EnergyMonitor_fourth_N=788 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_87]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_87
#
# running simulation for angle:  -0.03684210526315789
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_88"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 26 [s] % 41 51 61 71 81 91
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=2.6897e+08 EnergyMonitor_first_ERR=1.46553e+07 EnergyMonitor_first_N=1197 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=1.56308e+08 EnergyMonitor_second_ERR=1.02367e+07 EnergyMonitor_second_N=438 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=8.67205e+08 EnergyMonitor_third_ERR=1.15901e+08 EnergyMonitor_third_N=3231 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=1.90251e+08 EnergyMonitor_fourth_ERR=1.38233e+07 EnergyMonitor_fourth_N=885 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_88]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_88
#
# running simulation for angle:  -0.02631578947368421
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_89"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 25 [s] % 43 53 63 73 83 93
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=1.61653e+09 EnergyMonitor_first_ERR=9.05173e+07 EnergyMonitor_first_N=2743 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=9.10157e+08 EnergyMonitor_second_ERR=7.40766e+07 EnergyMonitor_second_N=1308 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=3.6187e+09 EnergyMonitor_third_ERR=1.22583e+08 EnergyMonitor_third_N=6670 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=1.20248e+09 EnergyMonitor_fourth_ERR=9.30057e+07 EnergyMonitor_fourth_N=2247 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_89]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_89
#
# running simulation for angle:  -0.015789473684210527
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_90"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 26 [s] % 42 52 62 72 82 92
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=4.24813e+09 EnergyMonitor_first_ERR=1.12759e+08 EnergyMonitor_first_N=3259 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=1.88845e+09 EnergyMonitor_second_ERR=7.6598e+07 EnergyMonitor_second_N=1307 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.18476e+10 EnergyMonitor_third_ERR=2.00645e+08 EnergyMonitor_third_N=9325 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.44492e+09 EnergyMonitor_fourth_ERR=1.11221e+08 EnergyMonitor_fourth_N=2662 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_90]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_90
#
# running simulation for angle:  -0.005263157894736843
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_91"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 26 [s] % 41 51 61 71 81 91
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=8.56019e+09 EnergyMonitor_first_ERR=1.50511e+08 EnergyMonitor_first_N=6196 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=4.40935e+09 EnergyMonitor_second_ERR=1.10701e+08 EnergyMonitor_second_N=2904 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=2.22301e+10 EnergyMonitor_third_ERR=2.50374e+08 EnergyMonitor_third_N=15977 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=7.03498e+09 EnergyMonitor_fourth_ERR=1.36802e+08 EnergyMonitor_fourth_N=4988 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_91]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_91
#
# running simulation for angle:  0.005263157894736841
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_92"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 23 [s] % 45 55 65 75 85 95
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=1.0133e+10 EnergyMonitor_first_ERR=1.66353e+08 EnergyMonitor_first_N=7162 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=4.89741e+09 EnergyMonitor_second_ERR=1.13113e+08 EnergyMonitor_second_N=3260 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=2.80075e+10 EnergyMonitor_third_ERR=2.91617e+08 EnergyMonitor_third_N=19202 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=9.39629e+09 EnergyMonitor_fourth_ERR=1.65899e+08 EnergyMonitor_fourth_N=6248 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_92]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_92
#
# running simulation for angle:  0.015789473684210527
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_93"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 27 [s] % 40 50 60 70 80 90
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=4.84931e+09 EnergyMonitor_first_ERR=1.46192e+08 EnergyMonitor_first_N=3967 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=1.79506e+09 EnergyMonitor_second_ERR=6.69709e+07 EnergyMonitor_second_N=1497 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.56042e+10 EnergyMonitor_third_ERR=2.43076e+08 EnergyMonitor_third_N=13658 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=5.58669e+09 EnergyMonitor_fourth_ERR=1.48705e+08 EnergyMonitor_fourth_N=4388 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_93]. Time: 27 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_93
#
# running simulation for angle:  0.02631578947368421
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_94"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 27 [s] % 40 50 60 70 80 90
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=2.64313e+09 EnergyMonitor_first_ERR=1.04424e+08 EnergyMonitor_first_N=3588 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=1.58814e+09 EnergyMonitor_second_ERR=6.19065e+07 EnergyMonitor_second_N=1883 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=8.00985e+09 EnergyMonitor_third_ERR=1.95694e+08 EnergyMonitor_third_N=10653 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=2.79574e+09 EnergyMonitor_fourth_ERR=8.81741e+07 EnergyMonitor_fourth_N=3735 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_94]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_94
#
# running simulation for angle:  0.03684210526315789
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_95"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 23 [s] % 46 56 66 76 86 96
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=4.47813e+08 EnergyMonitor_first_ERR=2.38682e+07 EnergyMonitor_first_N=1968 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=1.38308e+08 EnergyMonitor_second_ERR=1.09687e+07 EnergyMonitor_second_N=782 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=2.07307e+09 EnergyMonitor_third_ERR=7.42027e+07 EnergyMonitor_third_N=6991 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=6.57879e+08 EnergyMonitor_fourth_ERR=4.36688e+07 EnergyMonitor_fourth_N=2396 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_95]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_95
#
# running simulation for angle:  0.047368421052631574
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_96"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 31 [s] % 34 44 54 64 74 84 94
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=9.74414e+06 EnergyMonitor_first_ERR=816605 EnergyMonitor_first_N=867 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.31087e+06 EnergyMonitor_second_ERR=549176 EnergyMonitor_second_N=344 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=4.75529e+08 EnergyMonitor_third_ERR=2.8276e+07 EnergyMonitor_third_N=5208 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=9.51557e+07 EnergyMonitor_fourth_ERR=8.75538e+06 EnergyMonitor_fourth_N=1485 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_96]. Time: 31 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_96
#
# running simulation for angle:  0.057894736842105256
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_97"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 30 [s] % 36 46 56 66 76 86 96
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=385908 EnergyMonitor_first_ERR=52017.5 EnergyMonitor_first_N=471 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=52436.5 EnergyMonitor_second_ERR=21105.1 EnergyMonitor_second_N=75 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.01827e+08 EnergyMonitor_third_ERR=8.35932e+06 EnergyMonitor_third_N=3286 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=7.17744e+06 EnergyMonitor_fourth_ERR=1.8062e+06 EnergyMonitor_fourth_N=953 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_97]. Time: 25 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_97
#
# running simulation for angle:  0.06842105263157894
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_98"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 24 [s] % 45 55 65 75 85 95
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=2334.2 EnergyMonitor_first_ERR=636.14 EnergyMonitor_first_N=106 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=2246.15 EnergyMonitor_second_ERR=638.372 EnergyMonitor_second_N=43 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.26805e+06 EnergyMonitor_third_ERR=373360 EnergyMonitor_third_N=1293 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=14593.9 EnergyMonitor_fourth_ERR=7111.6 EnergyMonitor_fourth_N=281 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_98]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_98
#
# running simulation for angle:  0.07894736842105263
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_99"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 22 [s] % 48 58 68 78 88 98
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0.236412 EnergyMonitor_first_ERR=0.219523 EnergyMonitor_first_N=33 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.53715e-05 EnergyMonitor_second_ERR=4.33211e-05 EnergyMonitor_second_N=2 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=9222.42 EnergyMonitor_third_ERR=1394.64 EnergyMonitor_third_N=1068 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=565.001 EnergyMonitor_fourth_ERR=122.548 EnergyMonitor_fourth_N=272 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_99]. Time: 22 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_99
#
# running simulation for angle:  0.08947368421052632
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_100"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 26 [s] % 42 52 62 72 82 92
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0 EnergyMonitor_first_ERR=0 EnergyMonitor_first_N=0 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=0 EnergyMonitor_second_ERR=0 EnergyMonitor_second_N=0 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=37.0861 EnergyMonitor_third_ERR=13.6366 EnergyMonitor_third_N=263 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=0.146463 EnergyMonitor_fourth_ERR=0.0935539 EnergyMonitor_fourth_N=60 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_100]. Time: 25 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_100
#
# running simulation for angle:  0.1
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_101"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 24 [s] % 45 55 65 75 85 95
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=0 EnergyMonitor_first_ERR=0 EnergyMonitor_first_N=0 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=0 EnergyMonitor_second_ERR=0 EnergyMonitor_second_N=0 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=0.0590457 EnergyMonitor_third_ERR=0.0208263 EnergyMonitor_third_N=26 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=0 EnergyMonitor_fourth_ERR=0 EnergyMonitor_fourth_N=0 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_101]. Time: 24 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_101

# %% [markdown]
# ##### Comparing with and without detuning

# %%
# --------------------------------- Input fwhm of the rocking curve above for that energy (6900 eV)
fwhm_of_rocking_curve = float(input("Input approximate fwhm of the rocking curve found above(deg):")) 
det_percent_of_rocking_curve = float(input("Input percentage of the fwhm to detune the second crystal by (40 or 50 for example) (%):")) 

dict_params["fwhm"] = fwhm_of_rocking_curve #0.1
dict_params["detuning_percentage"] = det_percent_of_rocking_curve
#put this back to 0
dict_params["detuning_rockingcurve"] = 0

print("running simulation with the 2nd crystal detuned by ",det_percent_of_rocking_curve, "% of the fwhm = ",
      fwhm_of_rocking_curve)

my_instrument.set_parameters(dict_params)
data = my_instrument.backengine()
data_list = []
data_list.append(data)

print("running simulation with the 2nd crystal not detuned.")
dict_params["detuning_percentage"] = 0

my_instrument.set_parameters(dict_params)
data = my_instrument.backengine()
data_list.append(data)

print("With detuning, no or little harmonics.")
ms.make_sub_plot(data_list[0][0])

print("Without detuning, harmonics are present.")
ms.make_sub_plot(data_list[1][0])
#You can also look at the 4 monitors at the same time, uncomment below if you wish to do so
#ms.make_sub_plot(data_list[0][0])
#ms.make_sub_plot(data_list[1][0])
# Out:
# Input approximate fwhm of the rocking curve found above(deg):0.1
# Input percentage of the fwhm to detune the second crystal by (40 or 50 for example) (%):40
# running simulation with the 2nd crystal detuned by  40.0 % of the fwhm =  0.1
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_102"
# INFO: Regenerating c-file: mcstasscript_bl_11_2_white_src.c
# Warning: Component Origin=Progress_bar(string profile) definition parameter
#          may be changed into a setting parameter to avoid
#          warnings at compile time.
# Info:    Defining SPLIT from bragg_crystal_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# Info:    Defining SPLIT from bragg_crystal_two_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# CFLAGS=
#           INFO: Recompiling: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0.04
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 23 [s] % 47 57 67 77 87 97
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=1.85006e+08 EnergyMonitor_first_ERR=1.36868e+07 EnergyMonitor_first_N=1275 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=5.22364e+07 EnergyMonitor_second_ERR=4.83129e+06 EnergyMonitor_second_N=417 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=1.51798e+09 EnergyMonitor_third_ERR=5.16545e+07 EnergyMonitor_third_N=5968 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=4.30614e+08 EnergyMonitor_fourth_ERR=2.17911e+07 EnergyMonitor_fourth_N=1825 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_102]. Time: 23 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_102
#
# running simulation with the 2nd crystal not detuned.
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_103"
# INFO: Regenerating c-file: mcstasscript_bl_11_2_white_src.c
# Warning: Component Origin=Progress_bar(string profile) definition parameter
#          may be changed into a setting parameter to avoid
#          warnings at compile time.
# Info:    Defining SPLIT from bragg_crystal_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# Info:    Defining SPLIT from bragg_crystal_two_split=Single_crystal() to END in instrument mcstasscript_bl_11_2_white_src
# CFLAGS=
#           INFO: Recompiling: ./mcstasscript_bl_11_2_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# n 8
# Energy eV 6900 / Angle deg 27.8982
# theta_detuning degrees 0
# [mcstasscript_bl_11_2_white_src] Initialize
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: bragg_crystal_two_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Trace ETA 25 [s] % 43 53 63 73 83 93
#
# Save [mcstasscript_bl_11_2_white_src]
# Detector: EnergyMonitor_first_I=7.79196e+09 EnergyMonitor_first_ERR=1.4916e+08 EnergyMonitor_first_N=5329 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.19884e+09 EnergyMonitor_second_ERR=9.04555e+07 EnergyMonitor_second_N=2131 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=2.59701e+10 EnergyMonitor_third_ERR=2.79252e+08 EnergyMonitor_third_N=17008 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=7.61343e+09 EnergyMonitor_fourth_ERR=1.51726e+08 EnergyMonitor_fourth_N=4927 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_103]. Time: 25 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/mcxtrace_white_src/rocking_curve/bl_11_2_white_src_res_103
#
# McStasData: EnergyMonitor_first type: 1D  I:7791960000.0 E:149160000.0 N:5329.0
# '\nplt.title("No detuning.")\nplt.xlabel("Energy (eV)")\nplt.ylabel("I")\n\nplt.plot(X_rocking, Y_rocking, marker=\'.\', color="g", label=\'McXtrace\')\n\nplt.legend(fontsize=10)\nplt.show()\n\n\nplt.title("With detuning"+str(det_percent_of_rocking_curve)+"% of the RC\'s fwhm")\nplt.xlabel("Energy (eV)")\nplt.ylabel("I")\n\nplt.plot(X_rocking, Y_rocking, marker=\'.\', color="g", label=\'McXtrace\')\n\nplt.legend(fontsize=10)\nplt.show()'

# %% [markdown]
# ##### Energy scan

# %%
# -------------------------------------------------------------------------- Input energy range to scan
energy_initial = int(input("Input initial energy(eV):"))
energy_final = int(input("Input final energy(eV):"))

energy_scan_range = []

egy = energy_initial
while egy<=energy_final:
    energy_scan_range.append(str(egy))
    #print(egy)
    egy+=1

#print("energy_scan_range", energy_scan_range)
data_list = []

for energy in energy_scan_range:
    dict_params["Etohit"] = energy
    print("running simulation for energy: ",energy)
    my_instrument.set_parameters(dict_params)
    data = my_instrument.backengine()
    data_list.append(data)
    my_instrument.settings(force_compile=False)
    
my_instrument.settings(force_compile=True)

#writing the equivalent of mccode.dat, getting the total intensity of the 4 monitors
counter = 0

with open('./mcxtrace_bl_11_2_white_src/energy_scan/mccode_mcstasscript_white_src.dat', 'w') as f:    
    for energy in energy_scan_range:
        #print(energy)
        f.write(energy)
        f.write(" "+data_list[counter][0].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][1].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][2].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][3].metadata.info['values'].split(" ")[0])        
        f.write("\n")    
        counter+=1
        
print("Instrument BL 11-2 white source run.")

# %% [markdown]
# #### Monochromatic light

# %%
import mcstasscript as ms

my_instrument = ms.McXtrace_instr("mcstasscript_bl_11_2_not_white_src",input_path="./mcxtrace_bl_11_2_not_white_src")

dict_params = {}

dict_params["Etohit"] = "6900"
dict_params["h"] = "2"
dict_params["k"] = "2"
dict_params["l"] = "0"

my_instrument.add_parameter("Etohit")
my_instrument.add_parameter("h")
my_instrument.add_parameter("k")
my_instrument.add_parameter("l")

my_instrument.set_parameters(dict_params)

my_instrument.add_declare_var("double", "n")
my_instrument.add_declare_var("double", "calculated_angle")

my_instrument.append_initialize("n = h*h + k*k + l*l;")
my_instrument.append_initialize("fprintf(stdout,\"n %g \\n\", n);")
my_instrument.append_initialize("calculated_angle=RAD2DEG*asin(12398.4198*sqrt(n)/(2*5.43096*Etohit));")
my_instrument.append_initialize("fprintf(stdout,\"Energy eV %g / Angle deg %g \\n\", Etohit, calculated_angle);")
    
my_origin = my_instrument.add_component("Origin", "Progress_bar", AT=[0,0,0])

#my_instrument.show_parameters()

my_source = my_instrument.add_component("src", "Wiggler", AT=[0,0,0], RELATIVE="PREVIOUS")
my_source.E0 = "Etohit/1000"
my_source.dE = 100/1000
my_source.B = 2
my_source.Nper = 13
my_source.Ie = 0.1
my_source.length = 175e-3
my_source.Ee = 2.4
my_source.focus_xw = "2*tan(0.0015/2)"
my_source.focus_yh = "2*tan(0.00015/2)"

my_slit_mono = my_instrument.add_component("slit_mono", "Slit", AT=[0,0,17.6-0.08], RELATIVE="PREVIOUS")
my_slit_mono.xwidth = 0.005
my_slit_mono.yheight = 0.0003

my_mono_loc = my_instrument.add_component("mono_loc", "Arm", AT=[0,0,0.08], RELATIVE="PREVIOUS")

#ray's position, this is used to place monitors after the dcm
my_ray_position = my_instrument.add_component("ray_position", "Arm", AT=[0,0,0], RELATIVE="PREVIOUS")

# -------------------------------------------------------------------------- Double crystal monochromator 
my_mono_rotation = my_instrument.add_component("mono_rotation", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[-90,0,0], ROTATED_RELATIVE="PREVIOUS")

my_mono_rotation_phi_90 = my_instrument.add_component("mono_rotation_phi_90", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[0,0,-90], ROTATED_RELATIVE="PREVIOUS")

#0.006 works too though
my_center_of_rotation = my_instrument.add_component("center_of_rotation", "Arm", AT=[0,0,0.004], AT_RELATIVE="PREVIOUS", ROTATED=[0,"-calculated_angle",0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_no_split = my_instrument.add_component("bragg_crystal_no_split", "Single_crystal", AT=[-0.0762/2, 0, -0.006/2-(0.001/2)], AT_RELATIVE="PREVIOUS",ROTATED=[0,0,0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_no_split.reflections = "\"Si.lau\""
my_bragg_crystal_no_split.material = "\"Si.txt\""
my_bragg_crystal_no_split.xwidth = 76.2e-3
my_bragg_crystal_no_split.yheight =  41.275e-3
my_bragg_crystal_no_split.zdepth = 0.001
my_bragg_crystal_no_split.p_transmit = -1
my_bragg_crystal_no_split.order = 1
my_bragg_crystal_no_split.mosaic = 1
my_bragg_crystal_no_split.barns = 1
my_bragg_crystal_no_split.ax = -5.43096*0.40824829
my_bragg_crystal_no_split.ay = -5.43096*0.57735027
my_bragg_crystal_no_split.az = 5.43096*0.70710678
my_bragg_crystal_no_split.bx = 5.43096*0.40824829
my_bragg_crystal_no_split.by = 5.43096*0.57735027
my_bragg_crystal_no_split.bz = 5.43096*0.70710678
my_bragg_crystal_no_split.cx = -5.43096*0.81649658
my_bragg_crystal_no_split.cy = 5.43096*0.57735027
my_bragg_crystal_no_split.cz = 5.43096*0
my_bragg_crystal_no_split.append_EXTEND("if(!SCATTERED) ABSORB;")

my_mono_loc_2 = my_instrument.add_component("mono_loc_2", "Arm", AT=[0.09525/2, 0, 0.006/2+(0.001/2)], RELATIVE="center_of_rotation")

#no need for detuning here because source is not white
my_detuning_rotation = my_instrument.add_component("detuning_rotation", "Arm", AT=[0,0,0], AT_RELATIVE="PREVIOUS", ROTATED=[0,0,0], ROTATED_RELATIVE="PREVIOUS")

my_bragg_crystal_two_no_split = my_instrument.copy_component("bragg_crystal_two_no_split", "bragg_crystal_no_split", AT=[0, 0, 0], AT_RELATIVE="PREVIOUS",ROTATED=[0,0,0], ROTATED_RELATIVE="PREVIOUS")
my_bragg_crystal_two_no_split.xwidth = 95.25e-3
my_bragg_crystal_two_no_split.append_EXTEND("if(!SCATTERED) ABSORB;")

# -------------------------------------------------------------------------- Energy monitors
my_EnergyMonitor_first = my_instrument.add_component("EnergyMonitor_first", "Monitor_nD", AT=[0, "0.006*sin(DEG2RAD*2*calculated_angle)/sin(DEG2RAD*calculated_angle)", 18.6-17.6], RELATIVE="ray_position")
my_EnergyMonitor_first.xwidth = 44e-4
my_EnergyMonitor_first.yheight = 44e-4
my_EnergyMonitor_first.min = 4
my_EnergyMonitor_first.max =  40
my_EnergyMonitor_first.bins = 500
my_EnergyMonitor_first.options = "\"energy\""
my_EnergyMonitor_first.filename = "\"EnergyMonitor_first\""
my_EnergyMonitor_first.restore_xray = 1

my_EnergyMonitor_second = my_instrument.copy_component("EnergyMonitor_second", "EnergyMonitor_first", AT=[0, 0, 0], RELATIVE="PREVIOUS")
my_EnergyMonitor_second.xwidth = 2.8e-3
my_EnergyMonitor_second.yheight = 2.8e-3
my_EnergyMonitor_second.filename = "\"EnergyMonitor_second\""

my_EnergyMonitor_third = my_instrument.copy_component("EnergyMonitor_third", "EnergyMonitor_first", AT=[0, 0, 10], RELATIVE="PREVIOUS")
my_EnergyMonitor_third.xwidth = 1e-2
my_EnergyMonitor_third.yheight = 1e-2
my_EnergyMonitor_third.filename = "\"EnergyMonitor_third\""

my_EnergyMonitor_fourth = my_instrument.copy_component("EnergyMonitor_fourth", "EnergyMonitor_first", AT=[0, 0, 0], RELATIVE="PREVIOUS")
my_EnergyMonitor_fourth.xwidth = 4.3e-3
my_EnergyMonitor_fourth.yheight = 4.3e-3
my_EnergyMonitor_fourth.filename = "\"EnergyMonitor_fourth\""

my_instrument.settings(output_path="./mcxtrace_bl_11_2_not_white_src/energy_scan/bl_11_2_not_white_src_res", ncount=1E7)

# -------------------------------------------------------------------------- Input energy range to scan
energy_initial = int(input("Input initial energy(eV):"))
energy_final = int(input("Input final energy(eV):"))

energy_scan_range = []

egy = energy_initial
while egy<=energy_final:
    energy_scan_range.append(str(egy))
    #print(egy)
    egy+=1

#print("energy_scan_range", energy_scan_range)
data_list = []

for energy in energy_scan_range:
    dict_params["Etohit"] = energy
    print("running simulation for energy: ",energy)
    my_instrument.set_parameters(dict_params)
    data = my_instrument.backengine()
    data_list.append(data)
    my_instrument.settings(force_compile=False)
    
my_instrument.settings(force_compile=True)

#writing the equivalent of mccode.dat, getting the total intensity of the 4 monitors
counter = 0

with open('./mcxtrace_bl_11_2_not_white_src/energy_scan/mccode_mcstasscript_not_white_src.dat', 'w') as f:    
    for energy in energy_scan_range:
        #print(energy)
        f.write(energy)
        f.write(" "+data_list[counter][0].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][1].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][2].metadata.info['values'].split(" ")[0])
        f.write(" "+data_list[counter][3].metadata.info['values'].split(" ")[0])        
        f.write("\n")    
        counter+=1

print("Instrument BL 11-2 (nearly) mono source run.")
# Out:
# Input initial energy(eV):9818
# Input final energy(eV):10040
# 9818
# 9819
# 9820
# 9821
# 9822
# 9823
# 9824
# 9825
# 9826
# 9827
# 9828
# 9829
# 9830
# 9831
# 9832
# 9833
# 9834
# 9835
# 9836
# 9837
# 9838
# 9839
# 9840
# 9841
# 9842
# 9843
# 9844
# 9845
# 9846
# 9847
# 9848
# 9849
# 9850
# 9851
# 9852
# 9853
# 9854
# 9855
# 9856
# 9857
# 9858
# 9859
# 9860
# 9861
# 9862
# 9863
# 9864
# 9865
# 9866
# 9867
# 9868
# 9869
# 9870
# 9871
# 9872
# 9873
# 9874
# 9875
# 9876
# 9877
# 9878
# 9879
# 9880
# 9881
# 9882
# 9883
# 9884
# 9885
# 9886
# 9887
# 9888
# 9889
# 9890
# 9891
# 9892
# 9893
# 9894
# 9895
# 9896
# 9897
# 9898
# 9899
# 9900
# 9901
# 9902
# 9903
# 9904
# 9905
# 9906
# 9907
# 9908
# 9909
# 9910
# 9911
# 9912
# 9913
# 9914
# 9915
# 9916
# 9917
# 9918
# 9919
# 9920
# 9921
# 9922
# 9923
# 9924
# 9925
# 9926
# 9927
# 9928
# 9929
# 9930
# 9931
# 9932
# 9933
# 9934
# 9935
# 9936
# 9937
# 9938
# 9939
# 9940
# 9941
# 9942
# 9943
# 9944
# 9945
# 9946
# 9947
# 9948
# 9949
# 9950
# 9951
# 9952
# 9953
# 9954
# 9955
# 9956
# 9957
# 9958
# 9959
# 9960
# 9961
# 9962
# 9963
# 9964
# 9965
# 9966
# 9967
# 9968
# 9969
# 9970
# 9971
# 9972
# 9973
# 9974
# 9975
# 9976
# 9977
# 9978
# 9979
# 9980
# 9981
# 9982
# 9983
# 9984
# 9985
# 9986
# 9987
# 9988
# 9989
# 9990
# 9991
# 9992
# 9993
# 9994
# 9995
# 9996
# 9997
# 9998
# 9999
# 10000
# 10001
# 10002
# 10003
# 10004
# 10005
# 10006
# 10007
# 10008
# 10009
# 10010
# 10011
# 10012
# 10013
# 10014
# 10015
# 10016
# 10017
# 10018
# 10019
# 10020
# 10021
# 10022
# 10023
# 10024
# 10025
# 10026
# 10027
# 10028
# 10029
# 10030
# 10031
# 10032
# 10033
# 10034
# 10035
# 10036
# 10037
# 10038
# 10039
# 10040
# energy_scan_range ['9818', '9819', '9820', '9821', '9822', '9823', '9824', '9825', '9826', '9827', '9828', '9829', '9830', '9831', '9832', '9833', '9834', '9835', '9836', '9837', '9838', '9839', '9840', '9841', '9842', '9843', '9844', '9845', '9846', '9847', '9848', '9849', '9850', '9851', '9852', '9853', '9854', '9855', '9856', '9857', '9858', '9859', '9860', '9861', '9862', '9863', '9864', '9865', '9866', '9867', '9868', '9869', '9870', '9871', '9872', '9873', '9874', '9875', '9876', '9877', '9878', '9879', '9880', '9881', '9882', '9883', '9884', '9885', '9886', '9887', '9888', '9889', '9890', '9891', '9892', '9893', '9894', '9895', '9896', '9897', '9898', '9899', '9900', '9901', '9902', '9903', '9904', '9905', '9906', '9907', '9908', '9909', '9910', '9911', '9912', '9913', '9914', '9915', '9916', '9917', '9918', '9919', '9920', '9921', '9922', '9923', '9924', '9925', '9926', '9927', '9928', '9929', '9930', '9931', '9932', '9933', '9934', '9935', '9936', '9937', '9938', '9939', '9940', '9941', '9942', '9943', '9944', '9945', '9946', '9947', '9948', '9949', '9950', '9951', '9952', '9953', '9954', '9955', '9956', '9957', '9958', '9959', '9960', '9961', '9962', '9963', '9964', '9965', '9966', '9967', '9968', '9969', '9970', '9971', '9972', '9973', '9974', '9975', '9976', '9977', '9978', '9979', '9980', '9981', '9982', '9983', '9984', '9985', '9986', '9987', '9988', '9989', '9990', '9991', '9992', '9993', '9994', '9995', '9996', '9997', '9998', '9999', '10000', '10001', '10002', '10003', '10004', '10005', '10006', '10007', '10008', '10009', '10010', '10011', '10012', '10013', '10014', '10015', '10016', '10017', '10018', '10019', '10020', '10021', '10022', '10023', '10024', '10025', '10026', '10027', '10028', '10029', '10030', '10031', '10032', '10033', '10034', '10035', '10036', '10037', '10038', '10039', '10040']
# 9818
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_16"
# INFO: Regenerating c-file: mcstasscript_bl_11_2_not_white_src.c
# Warning: Component Origin=Progress_bar(string profile) definition parameter
#          may be changed into a setting parameter to avoid
#          warnings at compile time.
# CFLAGS=
#           INFO: Recompiling: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9818 / Angle deg 19.1982
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.15986e+11 EnergyMonitor_first_ERR=3.61401e+09 EnergyMonitor_first_N=31440 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.3047e+11 EnergyMonitor_second_ERR=2.90011e+09 EnergyMonitor_second_N=18734 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.96745e+11 EnergyMonitor_third_ERR=3.8829e+09 EnergyMonitor_third_N=36885 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.22527e+11 EnergyMonitor_fourth_ERR=2.86069e+09 EnergyMonitor_fourth_N=19247 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_16]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_16
#
# 9819
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_17"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9819 / Angle deg 19.1962
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.24629e+11 EnergyMonitor_first_ERR=3.64466e+09 EnergyMonitor_first_N=31934 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.3666e+11 EnergyMonitor_second_ERR=2.92785e+09 EnergyMonitor_second_N=19107 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.01857e+11 EnergyMonitor_third_ERR=3.89926e+09 EnergyMonitor_third_N=37269 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.27728e+11 EnergyMonitor_fourth_ERR=2.88438e+09 EnergyMonitor_fourth_N=19515 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_17]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_17
#
# 9820
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_18"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9820 / Angle deg 19.1942
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.20626e+11 EnergyMonitor_first_ERR=3.62962e+09 EnergyMonitor_first_N=31741 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29213e+11 EnergyMonitor_second_ERR=2.8924e+09 EnergyMonitor_second_N=18798 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.99203e+11 EnergyMonitor_third_ERR=3.89014e+09 EnergyMonitor_third_N=37107 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.22744e+11 EnergyMonitor_fourth_ERR=2.86024e+09 EnergyMonitor_fourth_N=19394 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_18]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_18
#
# 9821
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_19"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9821 / Angle deg 19.1922
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.19155e+11 EnergyMonitor_first_ERR=3.62479e+09 EnergyMonitor_first_N=31933 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.31382e+11 EnergyMonitor_second_ERR=2.90511e+09 EnergyMonitor_second_N=18908 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.00509e+11 EnergyMonitor_third_ERR=3.89327e+09 EnergyMonitor_third_N=37504 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.26902e+11 EnergyMonitor_fourth_ERR=2.88097e+09 EnergyMonitor_fourth_N=19727 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_19]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_19
#
# 9822
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_20"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9822 / Angle deg 19.1901
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.17096e+11 EnergyMonitor_first_ERR=3.61703e+09 EnergyMonitor_first_N=31678 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29304e+11 EnergyMonitor_second_ERR=2.89314e+09 EnergyMonitor_second_N=18835 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.9634e+11 EnergyMonitor_third_ERR=3.88036e+09 EnergyMonitor_third_N=37041 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.25644e+11 EnergyMonitor_fourth_ERR=2.87328e+09 EnergyMonitor_fourth_N=19559 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_20]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_20
#
# 9823
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_21"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9823 / Angle deg 19.1881
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.12961e+11 EnergyMonitor_first_ERR=3.60169e+09 EnergyMonitor_first_N=31521 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.25998e+11 EnergyMonitor_second_ERR=2.8803e+09 EnergyMonitor_second_N=18607 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.9601e+11 EnergyMonitor_third_ERR=3.87968e+09 EnergyMonitor_third_N=37053 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.19693e+11 EnergyMonitor_fourth_ERR=2.8459e+09 EnergyMonitor_fourth_N=19286 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_21]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_21
#
# 9824
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_22"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9824 / Angle deg 19.1861
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.19468e+11 EnergyMonitor_first_ERR=3.62412e+09 EnergyMonitor_first_N=31783 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29758e+11 EnergyMonitor_second_ERR=2.89484e+09 EnergyMonitor_second_N=18775 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.98758e+11 EnergyMonitor_third_ERR=3.88682e+09 EnergyMonitor_third_N=37245 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.25617e+11 EnergyMonitor_fourth_ERR=2.87227e+09 EnergyMonitor_fourth_N=19527 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_22]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_22
#
# 9825
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_23"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9825 / Angle deg 19.184
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.21153e+11 EnergyMonitor_first_ERR=3.6302e+09 EnergyMonitor_first_N=31849 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29067e+11 EnergyMonitor_second_ERR=2.89068e+09 EnergyMonitor_second_N=18826 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.00724e+11 EnergyMonitor_third_ERR=3.89201e+09 EnergyMonitor_third_N=37413 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.23794e+11 EnergyMonitor_fourth_ERR=2.86198e+09 EnergyMonitor_fourth_N=19527 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_23]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_23
#
# 9826
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_24"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9826 / Angle deg 19.182
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.20431e+11 EnergyMonitor_first_ERR=3.62702e+09 EnergyMonitor_first_N=31864 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.33259e+11 EnergyMonitor_second_ERR=2.91084e+09 EnergyMonitor_second_N=18980 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.98251e+11 EnergyMonitor_third_ERR=3.88474e+09 EnergyMonitor_third_N=37305 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.25139e+11 EnergyMonitor_fourth_ERR=2.86959e+09 EnergyMonitor_fourth_N=19623 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_24]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_24
#
# 9827
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_25"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9827 / Angle deg 19.18
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.20995e+11 EnergyMonitor_first_ERR=3.62912e+09 EnergyMonitor_first_N=31773 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.30221e+11 EnergyMonitor_second_ERR=2.89764e+09 EnergyMonitor_second_N=18771 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.9969e+11 EnergyMonitor_third_ERR=3.88937e+09 EnergyMonitor_third_N=37212 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.24657e+11 EnergyMonitor_fourth_ERR=2.86804e+09 EnergyMonitor_fourth_N=19496 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_25]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_25
#
# 9828
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_26"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9828 / Angle deg 19.1779
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.16432e+11 EnergyMonitor_first_ERR=3.61444e+09 EnergyMonitor_first_N=31631 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.28721e+11 EnergyMonitor_second_ERR=2.89162e+09 EnergyMonitor_second_N=18682 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.96121e+11 EnergyMonitor_third_ERR=3.87824e+09 EnergyMonitor_third_N=37115 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.2115e+11 EnergyMonitor_fourth_ERR=2.85177e+09 EnergyMonitor_fourth_N=19332 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_26]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_26
#
# 9829
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_27"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9829 / Angle deg 19.1759
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.18755e+11 EnergyMonitor_first_ERR=3.62072e+09 EnergyMonitor_first_N=31683 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.31361e+11 EnergyMonitor_second_ERR=2.90219e+09 EnergyMonitor_second_N=18827 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.95981e+11 EnergyMonitor_third_ERR=3.8765e+09 EnergyMonitor_third_N=37068 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.22781e+11 EnergyMonitor_fourth_ERR=2.85898e+09 EnergyMonitor_fourth_N=19452 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_27]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_27
#
# 9830
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_28"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9830 / Angle deg 19.1739
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.18794e+11 EnergyMonitor_first_ERR=3.6258e+09 EnergyMonitor_first_N=31740 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29738e+11 EnergyMonitor_second_ERR=2.89791e+09 EnergyMonitor_second_N=18722 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.98505e+11 EnergyMonitor_third_ERR=3.88957e+09 EnergyMonitor_third_N=37249 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.24457e+11 EnergyMonitor_fourth_ERR=2.8686e+09 EnergyMonitor_fourth_N=19556 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_28]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_28
#
# 9831
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_29"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9831 / Angle deg 19.1719
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.19596e+11 EnergyMonitor_first_ERR=3.62624e+09 EnergyMonitor_first_N=31746 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.26404e+11 EnergyMonitor_second_ERR=2.88199e+09 EnergyMonitor_second_N=18625 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.00306e+11 EnergyMonitor_third_ERR=3.89325e+09 EnergyMonitor_third_N=37280 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.26083e+11 EnergyMonitor_fourth_ERR=2.87549e+09 EnergyMonitor_fourth_N=19580 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_29]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_29
#
# 9832
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_30"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9832 / Angle deg 19.1698
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.17039e+11 EnergyMonitor_first_ERR=3.61687e+09 EnergyMonitor_first_N=31780 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.29802e+11 EnergyMonitor_second_ERR=2.89647e+09 EnergyMonitor_second_N=18870 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=5.96414e+11 EnergyMonitor_third_ERR=3.87943e+09 EnergyMonitor_third_N=37264 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.23946e+11 EnergyMonitor_fourth_ERR=2.86543e+09 EnergyMonitor_fourth_N=19591 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_30]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_30
#
# 9833
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_31"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 9833 / Angle deg 19.1678
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.21644e+11 EnergyMonitor_first_ERR=3.63229e+09 EnergyMonitor_first_N=31778 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.30793e+11 EnergyMonitor_second_ERR=2.90041e+09 EnergyMonitor_second_N=18789 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.03593e+11 EnergyMonitor_third_ERR=3.90266e+09 EnergyMonitor_third_N=37297 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.24601e+11 EnergyMonitor_fourth_ERR=2.86854e+09 EnergyMonitor_fourth_N=19411 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_31]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_31
#
# 9834
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_32"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# ...
# n 8
# Energy eV 10035 / Angle deg 18.7674
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.45782e+11 EnergyMonitor_first_ERR=5.24013e+09 EnergyMonitor_first_N=31335 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.45379e+11 EnergyMonitor_second_ERR=4.15801e+09 EnergyMonitor_second_N=18127 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.30298e+11 EnergyMonitor_third_ERR=5.60183e+09 EnergyMonitor_third_N=39228 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.41623e+11 EnergyMonitor_fourth_ERR=4.11523e+09 EnergyMonitor_fourth_N=19232 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_233]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_233
#
# 10036
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_234"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 10036 / Angle deg 18.7655
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.32146e+11 EnergyMonitor_first_ERR=4.51148e+09 EnergyMonitor_first_N=31650 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.37077e+11 EnergyMonitor_second_ERR=3.56256e+09 EnergyMonitor_second_N=18315 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.16757e+11 EnergyMonitor_third_ERR=4.88634e+09 EnergyMonitor_third_N=39849 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.31957e+11 EnergyMonitor_fourth_ERR=3.53038e+09 EnergyMonitor_fourth_N=19395 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_234]. Time: 4 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_234
#
# 10037
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_235"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 10037 / Angle deg 18.7635
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.44321e+11 EnergyMonitor_first_ERR=4.49689e+09 EnergyMonitor_first_N=31964 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.43606e+11 EnergyMonitor_second_ERR=3.57733e+09 EnergyMonitor_second_N=18348 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.27213e+11 EnergyMonitor_third_ERR=4.79574e+09 EnergyMonitor_third_N=40371 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.36302e+11 EnergyMonitor_fourth_ERR=3.47976e+09 EnergyMonitor_fourth_N=19485 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_235]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_235
#
# 10038
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_236"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 10038 / Angle deg 18.7616
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.50964e+11 EnergyMonitor_first_ERR=4.40403e+09 EnergyMonitor_first_N=32445 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.48983e+11 EnergyMonitor_second_ERR=3.53266e+09 EnergyMonitor_second_N=18591 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.37502e+11 EnergyMonitor_third_ERR=4.74014e+09 EnergyMonitor_third_N=41206 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.43952e+11 EnergyMonitor_fourth_ERR=3.47462e+09 EnergyMonitor_fourth_N=19853 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_236]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_236
#
# 10039
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_237"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 10039 / Angle deg 18.7596
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.43288e+11 EnergyMonitor_first_ERR=4.25686e+09 EnergyMonitor_first_N=32351 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.47114e+11 EnergyMonitor_second_ERR=3.40154e+09 EnergyMonitor_second_N=18840 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.29351e+11 EnergyMonitor_third_ERR=4.57114e+09 EnergyMonitor_third_N=41502 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.38935e+11 EnergyMonitor_fourth_ERR=3.3396e+09 EnergyMonitor_fourth_N=19850 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_237]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_237
#
# 10040
#
# loading system configuration
# INFO: Using directory: "/home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_238"
# INFO: Using existing c-file: ./mcstasscript_bl_11_2_not_white_src.c
# INFO: Using existing binary: ./mcstasscript_bl_11_2_not_white_src.out
# INFO: ===
# Warning (src): Wiggler is an experimental component - testing is ongoing
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# WARNING: (Table_Rebin): Rebinning table from Si.txt would exceed 1M rows. Skipping.
# n 8
# Energy eV 10040 / Angle deg 18.7577
# [mcstasscript_bl_11_2_not_white_src] Initialize
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_no_split: Read 43744 reflections from file 'Si.lau'
# Opening input file '/usr/share/mcxtrace/1.7.1/tools/Python/mxrun/../mccodelib/../../../data/Si.txt' (Table_Read_Offset)
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
# Opening input file 'Si.lau' (Table_Read_Offset)
# Single_crystal: Si.lau structure a=[-2.21718,-3.13557,3.84027] b=[2.21718,3.13557,3.84027] c=[-4.43436,3.13557,0] V0=160.188
# Single_crystal: bragg_crystal_two_no_split: Read 43744 reflections from file 'Si.lau'
# atomic_weight 28.0855
# Single_crystal: Rebinning material data (Si.txt) for faster tracing...
# Single_crystal: bragg_crystal_two_no_split: Vc=160.188 [Angs] sigma_abs= (mu/rho)*0 [barn] sigma_inc=0 [barn] reflections=Si.lau
#
# Save [mcstasscript_bl_11_2_not_white_src]
# Detector: EnergyMonitor_first_I=5.48755e+11 EnergyMonitor_first_ERR=4.33287e+09 EnergyMonitor_first_N=32545 "EnergyMonitor_first.E"
# Detector: EnergyMonitor_second_I=3.51628e+11 EnergyMonitor_second_ERR=3.47507e+09 EnergyMonitor_second_N=18897 "EnergyMonitor_second.E"
# Detector: EnergyMonitor_third_I=6.37577e+11 EnergyMonitor_third_ERR=4.65192e+09 EnergyMonitor_third_N=42057 "EnergyMonitor_third.E"
# Detector: EnergyMonitor_fourth_I=3.42047e+11 EnergyMonitor_fourth_ERR=3.39814e+09 EnergyMonitor_fourth_N=19918 "EnergyMonitor_fourth.E"
#
# Finally [mcstasscript_bl_11_2_not_white_src: /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_238]. Time: 5 [s]
# INFO: Placing instr file copy mcstasscript_bl_11_2_not_white_src.instr in dataset /home/antoine/beamline_help_mcxtrace/cahier_work_starto/20_12_2022_enfin_je_commence_lol/cahier_only/cahier_ssrl/bl_11_2_not_white_src_res_238

# %% [markdown]
# # Results
#
# Python scripts plot the ssrl data overlapped with the "theory glitches" data and the McXtrace simulation data.
# For the McXtrace data the moving average is subtracted.
#
# One must be careful when zooming too much on the ssrl data because the digitalized plots are done from a picture so the positions of the ssrl glitches can shift when zoomed in on too much.
#
# ## Theory glitches, ssrl-glitch and McXtrace data
#
#
# ### Plot notebook scan
#
# Run the following code block to make the plots appear. The simulation needs to have run beforehand.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
########### Plot 

src_choice = int(input("Input (0) for mono source, (1) for white source:"))

if src_choice==0:
    data_mcxtrace_filename = "./mcxtrace_bl_11_2_not_white_src/energy_scan/mccode_mcstasscript_not_white_src.dat"
else:
    data_mcxtrace_filename = "./mcxtrace_bl_11_2_white_src/energy_scan/mccode_mcstasscript_white_src.dat"

import numpy as np
import matplotlib.pyplot as plt

########### Get data from digitalized_data.txt, the digitalized ssrl db data
data_ssrl = np.loadtxt("digitalized_data.txt", encoding='utf-8-sig',delimiter=";")
size_data_ssrl = len(data_ssrl)
X_ssrl = np.zeros(size_data_ssrl)
Y_ssrl = np.zeros(size_data_ssrl)

i=0
for elt in data_ssrl:    
    X_ssrl[i] = 1000.0*elt[0]
    Y_ssrl[i] = elt[1]
    i+=1

########### Get data from theory_itsty_firstxtal.dat, the theory glitches
data_theory_glitches = np.loadtxt("theory_itsty_firstxtal.dat")
size_data_theory_glitches = len(data_theory_glitches)
X_theory_glitches = np.zeros(size_data_theory_glitches)
Y_theory_glitches = np.zeros(size_data_theory_glitches)
i=0
for elt in data_theory_glitches:
    X_theory_glitches[i] = elt[0]
    #relative intensities are of interest.
    Y_theory_glitches[i] = -elt[1]*(30.69/71350.83)
    i+=1
           
########### Get data from McXtrace's mccode.dat
screen=1
data_mcxtrace = np.loadtxt(data_mcxtrace_filename)
size_data_mcxtrace = len(data_mcxtrace)
X_mcxtrace = np.zeros(size_data_mcxtrace)
Y_mcxtrace = np.zeros(size_data_mcxtrace)
Y_mcxtrace_nan = np.zeros(size_data_mcxtrace)
#what is above the threshold isn't a glitch
#what is under is
threshold = 0.999
not_in_glitch = 1
i=0
for elt in data_mcxtrace:    
    X_mcxtrace[i]=elt[0]
    Y_mcxtrace[i]=elt[screen]
    Y_mcxtrace_nan[i]=elt[screen]
    i+=1
      
max_Y_mcxtrace = max(Y_mcxtrace)    
 
#### Get rid of glitches, detect where they are and nan the portions, then replace the nans by interpolation       
i=0
for elt in data_mcxtrace:
    if i!=0 and i!=(size_data_mcxtrace-1):
      y_diff_sign = Y_mcxtrace[i]-Y_mcxtrace[i-1]
      if y_diff_sign<0:
        y_diff_sign = -1
        y_div = Y_mcxtrace[i]/Y_mcxtrace[i-1]
      else:
        y_diff_sign = 1
        y_div = Y_mcxtrace[i-1]/Y_mcxtrace[i]
        
      y_diff = np.abs(Y_mcxtrace[i]-Y_mcxtrace[i-1])
            
      if not_in_glitch==1:
        if y_div<threshold:
          not_in_glitch = 0          
      elif not_in_glitch==0: 
        if y_div>threshold:
          if(y_diff_sign>=1):
            if((Y_mcxtrace[i]/Y_mcxtrace[i+1])>threshold): #also the point after it
              not_in_glitch=1
          
      if not_in_glitch==0:
        Y_mcxtrace_nan[i] = np.nan
        
    i+=1    
    
not_nan = np.logical_not(np.isnan(Y_mcxtrace_nan))
indices = np.arange(len(Y_mcxtrace_nan))
without_glitches = np.interp(indices, indices[not_nan], Y_mcxtrace_nan[not_nan])
max_without_glitches = max(without_glitches)

for i,elt in enumerate(without_glitches):
    without_glitches[i]=(without_glitches[i]/max_without_glitches)*100

for i,elt in enumerate(Y_mcxtrace):
    Y_mcxtrace[i]=(Y_mcxtrace[i]/max_Y_mcxtrace)*100

#moving avg
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w
    
#window length of the moving avg
#nn=500 for the captures ecrans, compare
nn=50
o = moving_average(without_glitches, nn)
y_padded = np.pad(o, (nn//2, nn-1-nn//2), mode='edge')

print("shape",y_padded.shape,without_glitches.shape)

#Look at the normal plot and the plot without the glitches
#Check that it is correct before looking at the plot of Y_mcxtrace 
#plt.plot(X_mcxtrace, Y_mcxtrace, marker='x', color="r")
#plt.plot(X_mcxtrace, y_padded,marker='x', color="g")

#take off the moving avg without the glitches from the original plot with glitches
for i,elt in enumerate(Y_mcxtrace):
    Y_mcxtrace[i]=Y_mcxtrace[i]-y_padded[i]

#optional, you can try to bring a glitch to the same intensity as one of the ssrl glitches to see if the other glitches fit
for i,elt in enumerate(Y_mcxtrace):
    Y_mcxtrace[i]=Y_mcxtrace[i]*(30.69/95.69)

plt.title("Intensity deviation. Si 220 phi 90.")
plt.xlabel("E")
plt.ylabel("I deviation")

plt.plot(X_theory_glitches, Y_theory_glitches, marker='x', color="y", label='theory')

plt.plot(X_ssrl, Y_ssrl, marker='.', color="r", label='main db ssrl-db BL11-2')

plt.plot(X_mcxtrace, Y_mcxtrace, marker='.', color="g", label='McXtrace')

plt.legend(fontsize=10)
plt.show()
# Out:
# shape (223,) (223,)

# %% [markdown]
# ### Plots of entire range
#
# Here are plots that have been done for both sources from 4.5 to 27 keV.
#
# #### Monochromatic light
#
# ![moving avg substracted mono](images/ffffffffff.png)
#
# #### White light (use of detuning for harmonic rejection)
#
# ![moving avg substracted white](images/fffffffe.png)

# %% [markdown]
# # Interpretation
#
# Looking at the McXtrace data, the positions of the dips are (mostly) correct. The deviations intensities aren't.
# Some procedures done above might differ from the ones ssrl-glitch db has done and therefore lead to the deviations intensities not matching.
#
#
# ## Deviation intensity problem
#
# Using a large source leads to faulty intensity deviations because the statistics are not good enough. For example, the number of rays hitting the principal plane of diffraction is too low.
# A large source gives some intensity dips (also found on ssrl database) that are not seen when using a (nearly) monochromatic source.
#
# When using a (nearly) monochromatic source, the statistics are high enough, the glitches follow mostly the intensity deviations of their respective `F^2` reflections found in the Si.lau file.
# The source having an energy and angular divergence contributes to the "filling up" of glitches.
#
# To know more about the above, check the gitlab documentation found [here](gitlab link). Older documentation can also be found at the same place.

# %% [markdown]
# # Some resources used:
#
# [hkl plane visualizer](http://ressources.univ-lemans.fr/AccesLibre/UM/Pedago/physique/02/cristallo/planreti.html)
#
# [another hkl plane visualizer](http://lampx.tugraz.at/~hadley/ss1/crystalstructure/structures/diamond/diamond.php)
#
# [Crystallography and reciprocal space video](https://www.youtube.com/watch?v=DFFU39A3fPY)
#
# [Diamond crystal structure](https://web.iitd.ac.in/~ajeetk/AML736/Assignment2_Prob3.pdf)
#
# "Some considerations on glitches and the design of a double crystal monochromator with bent crystals", P. van Zuylen, M.J. van der Hoek, 248 / SP /E Vol. 733 Soft X -Ray Optics and Technology (1986)
#
# https://www-ssrl.slac.stanford.edu/mes/xafs/index.html#Detune
#
# https://www-ssrl.slac.stanford.edu/mes/11-2/manual.php
#
# https://www-ssrl.slac.stanford.edu/smbin/dataextractnew.pl?trace1=si22090112&trace2=None&trace3=None&trace4=None&lowrange=4.5&highrange=27&graph=1&kvalyes=0
#
# https://www-ssrl.slac.stanford.edu/mes/Glitch_Curves/
#
# https://www-ssrl.slac.stanford.edu/smbxas/beamlines/crystalsets.html
#
# https://www-ssrl.slac.stanford.edu/~xas/glitch/about_spectra.html
#
# https://accelconf.web.cern.ch/pac97/papers/pdf/6v049.pdf
#
# http://cds.cern.ch/record/553174/files/tucl6.pdf
#
# https://www-ssrl.slac.stanford.edu/mes/BL_11_update.htm
#
# link to the gitlab doc v1,v2,deviation problem!
